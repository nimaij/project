# %%
# Try another way to model LDA: 
# http://chrisstrelioff.ws/sandbox/2014/11/13/getting_started_with_latent_dirichlet_allocation_in_python.html
# To action:
# try test what topic you get for the first row
# Understand PC1 and 2 & relevance matrix

# %%
from sklearn import tree
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt

# %matplotlib inline

import pandas as pd
from sklearn import datasets
# Out:
# /Users/jiaminlim93/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
df= pd.read_csv('/Users/jiaminlim93/Desktop/GA Data Science Course/project/project/loan_use.csv',header=0)

# %%
# Do a small group to reduce computational time
sentences=df['loan_use'][0:1000].tolist()

# %%
len(sentences)
# Out:
# 1000

# %% [markdown]
# ## Cleaning data

# %% [markdown]
# ### Removing non-letters

# %%
import re

# %% [markdown]
# ### Tokenisation

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
raw = sentences[1].lower()
tokens = tokenizer.tokenize(raw)

# %%
tokens
# Out:
# ['purchase', 'hygiene', 'products', 'and', 'round', 'out', 'his', 'inventory']

# %% [markdown]
# ### Remove stop words

# %%
# !pip install stop-words
# Out:
# Requirement already satisfied: stop-words in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages

# %%
from stop_words import get_stop_words

# create English stop words list
en_stop = get_stop_words('en')

# %%
# remove stop words from tokens
stopped_tokens = [i for i in tokens if not i in en_stop]

print(stopped_tokens)
# Out:
# ['purchase', 'hygiene', 'products', 'round', 'inventory']

# %% [markdown]
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()

# %%
# stem token
stemmed_tokens = [p_stemmer.stem(i) for i in stopped_tokens]
print(stemmed_tokens)
# Out:
# [u'purchas', u'hygien', u'product', u'round', u'inventori']

# %% [markdown]
# ### Looping through every element in the list

# %%
#https://www.kaggle.com/c/word2vec-nlp-tutorial/details/part-1-for-beginners-bag-of-words
def description_to_words( raw_description ):
    # Function to convert a raw description to a string of words
    # The input is a single string (a raw loan use description), and 
    # the output is a single string (a preprocessed loan use description)
    #
    # 1. Remove non-letters
    letters_only = re.sub("[^a-zA-Z]", " ", raw_description)
    # 2.Tokenisation
    lower_letters_only = letters_only.lower()
    tokens = tokenizer.tokenize(lower_letters_only)
    # 3. Remove stop words
    stopped_tokens = [i for i in tokens if not i in en_stop]
    # 4. Stemming
    meaningful_words = [p_stemmer.stem(i) for i in stopped_tokens]
    return meaningful_words
    # 5. Join the words back into one string separated by space, 
    # and return the result.
    # return( " ".join( meaningful_words ))

# %%
clean_description = description_to_words(sentences[0])
print sentences[0]
print clean_description
# Out:
# Compra de ropa Jeans, blusas, camisas, pantalones y variedad para ni̱o.
# [u'compra', u'de', u'ropa', u'jean', u'blusa', u'camisa', u'pantalon', u'y', u'variedad', u'para', u'ni', u'o']

# %%
# Get the number of reviews based on the dataframe column size
num_descriptions = len(sentences)

# Initialize an empty list to hold the clean reviews
clean_descriptions = []

# Loop over each description; create an index i that goes from 0 to the length of the loan use description list 
# Inlcudes how long it takes to run
print "Cleaning and parsing the loan use data...\n"
clean_descriptions = []
for i in xrange( 0, num_descriptions ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print "Description %d of %d\n" % ( i+1, num_descriptions )                                                                    
    clean_descriptions.append( description_to_words( sentences[i] ) )
# Out:
# Cleaning and parsing the loan use data...
#
# Description 1000 of 1000

# %%
clean_descriptions
# Out:
# [[u'compra',
#   u'de',
#   u'ropa',
#   u'jean',
#   u'blusa',
#   u'camisa',
#   u'pantalon',
#   u'y',
#   u'variedad',
#   u'para',
#   u'ni',
#   u'o'],
#  [u'purchas', u'hygien', u'product', u'round', u'inventori'],
#  [u'rent',
#   u'shop',
#   u'purchas',
#   u'raw',
#   u'materi',
#   u'bicycl',
#   u'small',
#   u'cart'],
#  [u'go', u'rent', u'new', u'shop', u'enlarg', u'busi'],
#  [u'purchas', u'new', u'equip'],
#  [u'buy', u'paint', u'brush', u'materi', u'elei', u'wood', u'busi'],
#  [u'buy',
#   u'divers',
#   u'spare',
#   u'part',
#   u'compra',
#   u'de',
#   u'repuesto',
#   u'diverso'],
#  [u'busi', u'expans'],
#  [u'expand', u'poultri', u'busi'],
#  [u'addit',
#   u'work',
#   u'capit',
#   u'buy',
#   u'good',
#   u'improv',
#   u'kiosk',
#   u'condit'],
#  [u'purchas', u'vari', u'merchandis'],
#  [u'purchas', u'addit', u'stock', u'haircar', u'product', u'accessori'],
#  [u'buy', u'bag', u'maiz', u'gari'],
#  [u'stock', u'small', u'groceri', u'store'],
#  [u'purchas', u'fresh', u'fish'],
#  [u'buy', u'thread', u'shoe', u'decor'],
#  [u'purchas', u'plot', u'land', u'grow', u'rice'],
#  [u'buy', u'cow'],
#  [u'work', u'capit', u'greater', u'invest', u'product', u'gener', u'profit'],
#  [u'purchas', u'cow', u'cart'],
#  [u'nimia',
#   u'like',
#   u'purchas',
#   u'chees',
#   u'ingredi',
#   u'prepar',
#   u'chicken',
#   u'relleno',
#   u'sell'],
#  [u'buy', u'groceri', u'sell'],
#  [u'busi', u'capit'],
#  [u'purchas', u'cow'],
#  [u'buy', u'firewood', u'kitchen', u'utensil'],
#  [u'purchas', u'addtion', u'good', u'sari', u'sari', u'varieti', u'store'],
#  [u'purchas', u'inventori'],
#  [u'expand', u'small', u'livestock', u'busi'],
#  [u'purchas', u'drink', u'sell'],
#  [u'purchas', u'breed', u'livestock'],
#  [u'purchas', u'chemic', u'spray', u'gun', u'machet'],
#  [u'invest', u'expand', u'busi'],
#  [u'stock', u'busi'],
#  [u'addit', u'capit'],
#  [u'purchas', u'merchandis'],
#  [u'addit', u'capit', u'mainten', u'hog', u'rais', u'busi'],
#  [u'grow', u'busi'],
#  [u'purchas', u'cloth', u'increas', u'inventori'],
#  [u'purchas', u'construct', u'materi'],
#  [u'purchas', u'yam', u'sell'],
#  [u'buy', u'addit', u'milkfish', u'product', u'sell', u'varieti', u'store'],
#  [u'buy', u'farm', u'input'],
#  [u'pesticid', u'acaricid'],
#  [u'buy',
#   u'batteri',
#   u'rice',
#   u'veget',
#   u'oil',
#   u'cocoa',
#   u'candl',
#   u'cigarett',
#   u'soap',
#   u'mani',
#   u'item',
#   u'wholesal'],
#  [u'buy', u'tire', u'replac', u'part', u'motocarro'],
#  [u'buy',
#   u'two',
#   u'basin',
#   u'cola',
#   u'nut',
#   u'five',
#   u'contain',
#   u'palm',
#   u'oil'],
#  [u'strengthen', u'work', u'capit'],
#  [u'purchas', u'thread', u'sugar', u'color', u'flour', u'medicin', u'product'],
#  [u'purchas', u'addit', u'farm', u'suppli'],
#  [u'purchas', u'fertil', u'manur', u'farm', u'input'],
#  [u'purchas', u'freezer'],
#  [u'purchas', u'fertil', u'seed'],
#  [u'purchas', u'merchandis', u'begin', u'sell', u'hotdog'],
#  [u'make',
#   u'structur',
#   u'improv',
#   u'busi',
#   u'live',
#   u'condit',
#   u'build',
#   u'wall',
#   u'back',
#   u'shop'],
#  [u'suppli', u'busi', u'flower', u'pot'],
#  [u'purchas', u'shoe', u'cloth', u'cosmet', u'lotion', u'deodor', u'product'],
#  [u'buy', u'cook', u'ingredi', u'crockeri', u'cutleri'],
#  [u'buy',
#   u'build',
#   u'materi',
#   u'stone',
#   u'sand',
#   u'cement',
#   u'iron',
#   u'start',
#   u're',
#   u'build',
#   u'front',
#   u'hous',
#   u'abl',
#   u'decent',
#   u'home'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'buy', u'farmland', u'grow', u'coffe'],
#  [u'buy', u'piec', u'wood', u'make', u'bed', u'sell'],
#  [u'buy', u'larg', u'amount', u'groceri', u'product'],
#  [u'buy', u'paper', u'stationeri', u'product', u'wholesal'],
#  [u'purchas', u'rice', u'make', u'noodl'],
#  [u'purchas', u'tool', u'need', u'mainten', u'motorcycl'],
#  [u'purchas', u'cattl'],
#  [u'buy', u'cloth', u'sell'],
#  [u'purchas', u'vent', u'stove', u'use', u'bake', u'bread'],
#  [u'stock', u'fruit', u'veget', u'sell'],
#  [u'buy', u'chicken', u'feed', u'water'],
#  [u'buy',
#   u'shave',
#   u'machin',
#   u'surgic',
#   u'spirit',
#   u'util',
#   u'requir',
#   u'barber',
#   u'shop',
#   u'well',
#   u'buy',
#   u'groceri',
#   u'suppli',
#   u'offer',
#   u'sale'],
#  [u'buy', u'item', u'sell'],
#  [u'buy', u'towel', u'cloth', u'footwear', u'product'],
#  [u'purchas', u'stock', u'sell'],
#  [u'purchas',
#   u'plate',
#   u'dish',
#   u'orient',
#   u'style',
#   u'order',
#   u'increas',
#   u'rang',
#   u'good',
#   u'sell'],
#  [u'purchas', u'materi', u'metalwork', u'busi'],
#  [u'pay', u'feed', u'miscellan', u'improv', u'poultri', u'pig', u'busi'],
#  [u'support', u'labor', u'cost', u'rice', u'product'],
#  [u'buy', u'fabric'],
#  [u'buy', u'fertil', u'suppli'],
#  [u'purchas', u'peanut', u'millet', u'local', u'bean'],
#  [u'buy', u'fabric', u'make', u'backpack'],
#  [u'buy', u'water', u'pump', u'pump', u'machin'],
#  [u'purchas', u'addit', u'product', u'sell', u'gener', u'store'],
#  [u'purchas', u'sack', u'tomato', u'potato', u'green', u'veget'],
#  [u'buy', u'fish', u'ball', u'product', u'ingredi', u'need', u'busi'],
#  [u'buy',
#   u'seedl',
#   u'pay',
#   u'worker',
#   u'use',
#   u'machin',
#   u'will',
#   u'use',
#   u'till',
#   u'land'],
#  [u'invest', u'set', u'workspac', u'roof', u'wall'],
#  [u'pay', u'univers', u'fee'],
#  [u'buy',
#   u'appl',
#   u'orang',
#   u'tangerin',
#   u'pear',
#   u'lettuc',
#   u'among',
#   u'thing'],
#  [u'buy', u'one', u'bull', u'order', u'expand', u'busi'],
#  [u'purchas',
#   u'motorbik',
#   u'transport',
#   u'palm',
#   u'sugar',
#   u'sell',
#   u'local',
#   u'market'],
#  [u'buy', u'materi', u'water', u'electr', u'servic'],
#  [u'person', u'use'],
#  [u'buy',
#   u'crate',
#   u'soda',
#   u'rice',
#   u'maiz',
#   u'flour',
#   u'bag',
#   u'sugar',
#   u'carton',
#   u'salt'],
#  [u'compra',
#   u'de',
#   u'falda',
#   u'vestido',
#   u'zapato',
#   u'ropa',
#   u'interior',
#   u'calcetin',
#   u'blusa',
#   u'pantalon',
#   u'y',
#   u'tela'],
#  [u'buy', u'spare', u'part', u'compressor'],
#  [u'buy', u'merchandis', u'compra', u'de', u'mercanc'],
#  [u'increas', u'product', u'tailor', u'busi'],
#  [u'restock', u'shop'],
#  [u'buy', u'milk', u'cow'],
#  [u'replenish', u'suppli', u'groceri', u'store'],
#  [u'purchas', u'addit', u'stock', u'cloth', u'bulk'],
#  [u'expand', u'small', u'tire', u'servic', u'busi'],
#  [u'expand', u'farm', u'oper'],
#  [u'elsa',
#   u'nancia',
#   u'felicita',
#   u'need',
#   u'combin',
#   u'loan',
#   u'invest',
#   u'rice',
#   u'sugar',
#   u'noodl',
#   u'milk',
#   u'hen',
#   u'pork',
#   u'oil',
#   u'wheat'],
#  [u'buy', u'cloth', u'materi', u'assort', u'cosmet'],
#  [u'buy',
#   u'sack',
#   u'corn',
#   u'one',
#   u's',
#   u'meal',
#   u'cassavoc',
#   u'root',
#   u'one',
#   u'fish'],
#  [u'buy', u'refriger', u'restaur'],
#  [u'buy', u'yam', u'bulk'],
#  [u'purchas', u'addit', u'stock', u'tradit', u'african', u'cloth'],
#  [u'purchas', u'product', u'store'],
#  [u'enlarg', u'busi', u'replac', u'old', u'motorcycl'],
#  [u'work', u'capit'],
#  [u'buy', u'one', u'cow', u'also', u'fodder', u'farm', u'cattl'],
#  [u'purchas', u'land', u'add', u'groceri', u'product'],
#  [u'purchas', u'cow', u'resal'],
#  [u'suppli', u'shop'],
#  [u'procur', u'sachet', u'water'],
#  [u'purchas', u'sack', u'manioc', u'bolster', u'busi'],
#  [u'purchas', u'cattl'],
#  [u'buy', u'cloth', u'sell'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'invest', u'sari', u'sari', u'store'],
#  [u'build', u'new', u'brick', u'oven'],
#  [u'hire', u'peopl', u'plough', u'farmland'],
#  [u'busi', u'capit'],
#  [u'lo',
#   u'invertir',
#   u'en',
#   u'la',
#   u'compra',
#   u'de',
#   u'vald',
#   u'bolsa',
#   u'papa',
#   u'huevo',
#   u'az',
#   u'car',
#   u'etc'],
#  [u'buy', u'sack', u'charcoal'],
#  [u'addit', u'capit', u'buy', u'hog', u'feed', u'build', u'pig', u'pen'],
#  [u'purchas', u'use', u'footwear', u'men', u'women', u'children'],
#  [u'buy', u'offic', u'suppli', u'increas', u'stock'],
#  [u'purchas', u'product', u'expand', u'busi'],
#  [u'purchas', u'yam', u'sell'],
#  [u'purchas', u'cook', u'oil', u'egg', u'sell'],
#  [u'purchas', u'soft', u'drink'],
#  [u'purchas', u'corn', u'groundnut', u'bean', u'fowl'],
#  [u'buy', u'farm', u'suppli'],
#  [u'purchas', u'calv'],
#  [u'purchas', u'rice', u'corn', u'tomato', u'alcohol', u'beverag'],
#  [u'buy', u'addit', u'product', u'sell'],
#  [u'purchas', u'inventori', u'live', u'chicken', u'sale'],
#  [u'buy', u'manur', u'fertliz', u'insecticid', u'field'],
#  [u'purchas', u'bucket', u'basin', u'cup'],
#  [u'purchas', u'phone', u'accessori', u'batteri', u'charger', u'etc'],
#  [u'buy', u'four', u'piglet', u'pig', u'chicken', u'feed', u'fertil'],
#  [u'buy', u'bag', u'maiz', u'prepar', u'kenkey', u'sell'],
#  [u'purchas',
#   u'anoth',
#   u'bundl',
#   u'secondhand',
#   u'cloth',
#   u'order',
#   u'reinforc',
#   u'work',
#   u'capit'],
#  [u'work', u'capit'],
#  [u'purchas',
#   u'basic',
#   u'grain',
#   u'candi',
#   u'soda',
#   u'meat',
#   u'chicken',
#   u'dairi',
#   u'product',
#   u'school',
#   u'suppli',
#   u'product'],
#  [u'construct', u'complet', u'beauti', u'salon'],
#  [u'purchas', u'addit', u'inventori', u'work', u'capit'],
#  [u'purchas', u'dairi', u'cow'],
#  [u'purchas', u'rice', u'meat', u'veget'],
#  [u'purchas', u'addit', u'banana', u'buy', u'sell'],
#  [u'buy', u'merchandis'],
#  [u'purchas', u'addit', u'product', u'piglet'],
#  [u'buy',
#   u'motorbik',
#   u'attach',
#   u'trailer',
#   u'order',
#   u'transport',
#   u'rice',
#   u'sell'],
#  [u'build', u'hous'],
#  [u'buy', u'seed', u'farm', u'input'],
#  [u'construct', u'new', u'greenhous'],
#  [u'purchas', u'sugar', u'salt', u'soap', u'cook', u'oil'],
#  [u'purchas', u'educ', u'materi', u'daughter', u'pay', u'home', u'repair'],
#  [u'buy', u'season', u'good', u'resal'],
#  [u'buy', u'new', u'skullcap'],
#  [u'stock', u'food', u'market'],
#  [u'buy', u'groceri', u'sari', u'sari', u'store', u'school', u'suppli'],
#  [u'buy', u'retail', u'commod', u'resel'],
#  [u'buy',
#   u'new',
#   u'motorcycl',
#   u'provid',
#   u'taxi',
#   u'servic',
#   u'use',
#   u'commut'],
#  [u'purchas', u'motorcycl', u'can', u'get', u'work', u'time'],
#  [u'buy', u'fertil', u'farm', u'suppli'],
#  [u'buy', u'farm', u'suppli'],
#  [u'finish', u'room', u'front', u'hous'],
#  [u'buy', u'meat', u'sell', u'custom'],
#  [u'pay', u'children', u's', u'tuition', u'school', u'suppli', u'uniform'],
#  [u'spend', u'money', u'farm', u'purchas', u'sheep'],
#  [u'buy', u'blous', u'shirt', u'short'],
#  [u'buy', u'fertil', u'herbicid', u'pesticid', u'crop'],
#  [u'buy',
#   u'lipstick',
#   u'lip',
#   u'pencil',
#   u'powder',
#   u'cr',
#   u'me',
#   u'shampoo',
#   u'treatment',
#   u'lotion'],
#  [u'purchas', u'tea', u'leav'],
#  [u'purchas', u'tomato', u'onion', u'bean', u'sale'],
#  [u'buy', u'seed', u'fertil'],
#  [u'stock', u'store'],
#  [u'buy', u'rice', u'seed', u'fertil', u'farm'],
#  [u'capit', u'work', u'person', u'need'],
#  [u'buy', u'chicken'],
#  [u'purchas', u'timber', u'furnitur', u'make'],
#  [u'achat', u'de', u'divers', u'marchandis'],
#  [u'buy', u'seedl', u'fertil'],
#  [u'buy', u'groundnut', u'corn', u'veget'],
#  [u'like',
#   u'stock',
#   u'kiosk',
#   u'soap',
#   u'sugar',
#   u'bread',
#   u'doughnut',
#   u'yellow',
#   u'banana'],
#  [u'increas',
#   u'stock',
#   u'ingredi',
#   u'enabl',
#   u'cook',
#   u'food',
#   u'sale',
#   u'day'],
#  [u'buy',
#   u'weed',
#   u'kill',
#   u'chemic',
#   u'knive',
#   u'crowbar',
#   u'wheel',
#   u'barrow',
#   u'suppli',
#   u'veget',
#   u'garden'],
#  [u'buy', u'seedl'],
#  [u'purchas', u'ingredi', u'pastri', u'shop'],
#  [u'increas', u'varieti', u'phone', u'grow', u'busi'],
#  [u'purchas', u'milk', u'cow'],
#  [u'expand',
#   u'farm',
#   u'oper',
#   u'order',
#   u'meet',
#   u'target',
#   u'next',
#   u'year',
#   u's',
#   u'product',
#   u'farm'],
#  [u'addit', u'capit', u'buy', u'bread', u'egg', u'sell'],
#  [u'purchas',
#   u'motorcycl',
#   u'taxi',
#   u'p',
#   u'achat',
#   u'de',
#   u'taxi',
#   u'moto',
#   u'p'],
#  [u'buy',
#   u'box',
#   u'omo',
#   u'deterg',
#   u'box',
#   u'fanico',
#   u'soap',
#   u'sack',
#   u'rice',
#   u'liter',
#   u'drum',
#   u'oil'],
#  [u'purchas', u'groceri', u'stock', u'oxen'],
#  [u'purchas',
#   u'variou',
#   u'groceri',
#   u'item',
#   u'compra',
#   u'de',
#   u'diverso',
#   u'art',
#   u'culo',
#   u'abarrot'],
#  [u'purchas', u'part', u'vehicl'],
#  [u'invest', u'offer', u'stock', u'product'],
#  [u'ask', u'loan', u'buy', u'hen', u'add', u'busi', u'go', u'well'],
#  [u'buy',
#   u'high',
#   u'qualiti',
#   u'paddi',
#   u'seed',
#   u'fertil',
#   u'pesticid',
#   u'b'],
#  [u'purchas', u'spare', u'part', u'car'],
#  [u'buy',
#   u'one',
#   u'cow',
#   u'also',
#   u'fodder',
#   u'farm',
#   u'cattl',
#   u'order',
#   u'make',
#   u'number',
#   u'farm',
#   u'cattl'],
#  [u'use', u'grow', u'small', u'tree', u'sell'],
#  [u'buy', u'motorcycl', u'use', u'motor', u'taxi'],
#  [u'purchas', u'stock'],
#  [u'buy', u'merchandis'],
#  [u'purchas', u'deep', u'freezer', u'ice', u'block', u'sell'],
#  [u'increas', u'number', u'cattl'],
#  [u'dairi', u'cow'],
#  [u'invest', u'expand', u'busi'],
#  [u'purchas',
#   u'small',
#   u'cattl',
#   u'order',
#   u'expand',
#   u'busi',
#   u'improv',
#   u'live',
#   u'condit',
#   u'famili'],
#  [u'addit', u'capit', u'pamil', u'busi'],
#  [u'purchas', u'motorbik', u'deliv', u'dessert'],
#  [u'invest', u'expand', u'busi'],
#  [u'lo',
#   u'utilizara',
#   u'para',
#   u'comprar',
#   u'verdura',
#   u'y',
#   u'fruta',
#   u'menestra',
#   u'al',
#   u'por',
#   u'mayor'],
#  [u'request',
#   u'loan',
#   u'will',
#   u'use',
#   u'purchas',
#   u'assort',
#   u'merchandis',
#   u'sell'],
#  [u'purchas', u'sarong', u'sell'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'buy', u'teach', u'materi', u'like', u'toy', u'book'],
#  [u'buy', u'cereal', u'bulk', u'sell'],
#  [u'buy',
#   u'addit',
#   u'cosmet',
#   u'product',
#   u'like',
#   u'powder',
#   u'lotion',
#   u'deodor',
#   u'like'],
#  [u'purchas', u'candi'],
#  [u'achat',
#   u'de',
#   u'savon',
#   u'gobelet',
#   u'et',
#   u'bassin',
#   u'en',
#   u'plastiqu',
#   u'sucr',
#   u'pile',
#   u'etc'],
#  [u'purchas', u'egg', u'sell'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'invest', u'expand', u'busi'],
#  [u'buy', u'sheet', u'fabric'],
#  [u'purchas', u'school', u'suppli', u'notebook', u'book', u'etc'],
#  [u'use', u'addit', u'capit', u'fish', u'vend', u'busi'],
#  [u'purchas', u'gener', u'farm', u'suppli', u'equip'],
#  [u'buy', u'soft', u'drink', u'sell'],
#  [u'expand', u'busi'],
#  [u'buy', u'food', u'product'],
#  [u'purchas', u'wood', u'carpentri', u'busi'],
#  [u'purchas',
#   u'fabric',
#   u'thread',
#   u'sew',
#   u'busi',
#   u'invest',
#   u'cosmet',
#   u'custom',
#   u'order'],
#  [u'suppli'],
#  [u'purchas',
#   u'meat',
#   u'start',
#   u'butcher',
#   u'shop',
#   u'addit',
#   u'exist',
#   u'busi'],
#  [u'purchas', u'addit', u'product', u'buy', u'sell'],
#  [u'purchas', u'bread', u'busi'],
#  [u'purchas', u'cattl'],
#  [u'purchas', u'calf'],
#  [u'purchas', u'beer', u'cola', u'fruit', u'juic', u'water', u'etc'],
#  [u'purchas', u'pair', u'shoe', u'bag', u'resal'],
#  [u'buy', u'item', u'sell', u'canteen'],
#  [u'purchas', u'stock', u'sell'],
#  [u'buy', u'materi', u'make', u'textil'],
#  [u'purchas', u'cattl'],
#  [u'buy', u'motorbik'],
#  [u'purchas',
#   u'cloth',
#   u'frame',
#   u'canva',
#   u'needl',
#   u'button',
#   u'relat',
#   u'suppli',
#   u'etc'],
#  [u'buy', u'perfum', u'bead'],
#  [u'buy', u'dairi', u'cow'],
#  [u'purchas',
#   u'fertil',
#   u'manur',
#   u'well',
#   u'buy',
#   u'hybrid',
#   u'corn',
#   u'seed',
#   u'plant'],
#  [u'buy', u'materi', u'enlarg', u'hous'],
#  [u'buy',
#   u'bread',
#   u'sweet',
#   u'flour',
#   u'sugar',
#   u'basic',
#   u'grain',
#   u'dairi',
#   u'product',
#   u'beverag',
#   u'store'],
#  [u'purchas',
#   u'food',
#   u'rice',
#   u'cabbag',
#   u'pineappl',
#   u'maiz',
#   u'etc',
#   u'resel'],
#  [u'buy', u'school', u'suppli', u'paper', u'soda', u'juic', u'etc'],
#  [u'buy', u'merchandis', u'busi'],
#  [u'purchas', u'livestock', u'sell'],
#  [u'purchas',
#   u'coconut',
#   u'materi',
#   u'make',
#   u'flower',
#   u'color',
#   u'paper',
#   u'dye'],
#  [u'buy', u'suppli', u'coffe', u'plantat'],
#  [u'purchas', u'addit', u'seed', u'seedl', u'young', u'crop', u'rais'],
#  [u'buy', u'seed', u'fertil', u'insecticid', u'need', u'veget', u'product'],
#  [u'purchas', u'ground', u'nut'],
#  [u'add',
#   u'stock',
#   u'busi',
#   u'purchas',
#   u'hair',
#   u'oil',
#   u'product',
#   u'blow',
#   u'dryer',
#   u'machin'],
#  [u'sourc',
#   u'farm',
#   u'input',
#   u'seed',
#   u'fertil',
#   u'low',
#   u'price',
#   u'plant',
#   u'season'],
#  [u'purchas', u'two', u'dairi', u'cow', u'stock', u'livestock', u'feed'],
#  [u'buy', u'sugar', u'soap', u'resal'],
#  [u'buy', u'fresh', u'season', u'fruit', u'resel'],
#  [u'buy', u'perfum', u'cream', u'cosmet', u'etc'],
#  [u'buy',
#   u'person',
#   u'merchandis',
#   u'deodor',
#   u'nail',
#   u'polish',
#   u'makeup',
#   u'cloth',
#   u'offer',
#   u'client'],
#  [u'buy', u'thread', u'produc', u'machin', u'cover', u'order'],
#  [u'renov',
#   u'villag',
#   u'artist',
#   u'workshop',
#   u'addit',
#   u'restaur',
#   u'bar',
#   u'target',
#   u'tourist',
#   u'market'],
#  [u'purchas', u'hook', u'paint', u'brush', u'string'],
#  [u'buy', u'rice', u'mill'],
#  [u'buy',
#   u'wholesal',
#   u'product',
#   u'like',
#   u'oil',
#   u'sugar',
#   u'corn',
#   u'can',
#   u'product'],
#  [u'marguerit',
#   u'will',
#   u'use',
#   u'loan',
#   u'pay',
#   u'school',
#   u'expens',
#   u'purchas',
#   u'good',
#   u'busi'],
#  [u'buy', u'cow', u'busi'],
#  [u'expand', u'poultri', u'hous'],
#  [u'expand', u'electron', u'repair', u'shop', u'sever', u'small', u'busi'],
#  [u'buy', u'addit', u'cosmet', u'can', u'expand', u'client', u'base'],
#  [u'increas', u'capit', u'acquir', u'merchandis'],
#  [u'purchas', u'new', u'cloth', u'inventori'],
#  [u'begin', u'construct', u'porch', u'hous'],
#  [u'rais', u'livestock', u'busi'],
#  [u'buy', u'music', u'cd', u'bulk'],
#  [u'buy', u'sack', u'rice', u'liter', u'kerosen'],
#  [u'purchas', u'jacket', u'raincoat'],
#  [u'buy', u'piec', u'land', u'plant', u'rice'],
#  [u'purchas', u'piglet', u'pig', u'food', u'breed'],
#  [u'purchas', u'chemic', u'cabbag'],
#  [u'purchas', u'goat', u'cow', u'resal'],
#  [u'buy', u'cloth', u'resel'],
#  [u'purchas', u'fertil', u'insecticid'],
#  [u'purchas', u'cook', u'utensil', u'tabl'],
#  [u'buy', u'smoke', u'dri', u'fish'],
#  [u'buy',
#   u'basket',
#   u'green',
#   u'veget',
#   u'lettac',
#   u'coliflow',
#   u'cucumb',
#   u'carrot'],
#  [u'purchas', u'ingredi', u'make', u'cook', u'food', u'sell'],
#  [u'purchas', u'season', u'merchandis'],
#  [u'buy', u'new', u'car', u'engin'],
#  [u'expand', u'busi'],
#  [u'buy', u'groceri', u'husband', u's', u'groceri', u'shop'],
#  [u'servic', u'repair', u'taxi'],
#  [u'purchas', u'stock'],
#  [u'purchas', u'box', u'kinkon'],
#  [u'surtir', u'su', u'inventario'],
#  [u'buy', u'fertil'],
#  [u'stock', u'small', u'kiosk', u'help', u'grow', u'busi'],
#  [u'buy', u'fertil', u'coffe', u'banana', u'farm'],
#  [u'buy', u'sweet', u'snack'],
#  [u'buy', u'tabl', u'suppli', u'apricot', u'dri', u'sell'],
#  [u'increas', u'work', u'capit'],
#  [u'purchas', u'four', u'babi', u'calv'],
#  [u'start', u'fish', u'cage', u'busi'],
#  [u'invest', u'expand', u'busi'],
#  [u'purchas', u'sugar', u'rice'],
#  [u'purchas', u'bicycl', u'rim', u'tire', u'brake', u'chain', u'item'],
#  [u'invest', u'expand', u'busi'],
#  [u'increas', u'inventori'],
#  [u'repair', u'transport', u'vehicl', u'use', u'busi'],
#  [u'buy', u'fabric', u'firewood', u'rubber', u'bowl', u'larg', u'quantiti'],
#  [u'purchas', u'bag', u'crop', u'like', u'maiz', u'millet', u'bean'],
#  [u'buy', u'good', u'retail', u'store'],
#  [u'buy', u'scrap', u'metal', u'resal'],
#  [u'purchas', u'person', u'comput', u'aid', u'children', u's', u'studi'],
#  [u'buy', u'televis', u'set', u'dvd', u'player', u'tablecloth', u'other'],
#  [u'buy', u'calf'],
#  [u'buy', u'beam', u'tool', u'better', u'effici', u'job', u'bricklay'],
#  [u'join', u'commun', u'well'],
#  [u'fund', u'oper', u'fish', u'sell'],
#  [u'purchas', u'charcoal'],
#  [u'buy', u'stationeri', u'notebook', u'store'],
#  [u'purchas', u'high', u'grade', u'manur', u'farm', u'garden'],
#  [u'buy', u'suppli', u'improv', u'husband', u's', u'busi'],
#  [u'buy', u'seed', u'newborn', u'anim', u'mani', u'thing'],
#  [u'buy', u'cloth', u'add', u'stock'],
#  [u'purchas', u'good'],
#  [u'pay', u'colleg', u'fee', u'child', u'invest', u'remaind', u'busi'],
#  [u'purchas', u'tool', u'remov', u'field', u'brush'],
#  [u'buy',
#   u'corn',
#   u'firewood',
#   u'maintain',
#   u'kitchen',
#   u'prepar',
#   u'tortilla'],
#  [u'buy', u'vaccin', u'medicin', u'feed', u'poultri'],
#  [u'purchas',
#   u'addit',
#   u'product',
#   u'like',
#   u'soft',
#   u'drink',
#   u'sugar',
#   u'rice',
#   u'sell'],
#  [u'buy', u'peanut', u'butter', u'palm', u'oil', u'sell'],
#  [u'purchas', u'addit', u'groceri', u'item', u'sale'],
#  [u'buy', u'necessari', u'tool'],
#  [u'buy', u'seed', u'retail'],
#  [u'buy', u'paint', u'improv', u'decor', u'restaur'],
#  [u'buy', u'ingredi', u'fruit'],
#  [u'buy', u'merchandis', u'bazaar'],
#  [u'pay', u'labor', u'rice', u'farm'],
#  [u'buy', u'non', u'alcohol', u'beverag', u'corn'],
#  [u'purchas', u'blous', u't', u'shirt', u'pant', u'children', u's', u'cloth'],
#  [u'purchas', u'hen', u'resal'],
#  [u'buy', u'materi', u'finish', u'construct', u'hous'],
#  [u'buy', u'fuel', u'lubric', u'hay', u'feed', u'livestock'],
#  [u'buy', u'new', u'equip', u'hairdress', u'salon'],
#  [u'purchas', u'construct', u'suppli', u'expand', u'busi'],
#  [u'buy', u'leather', u'shoe', u'resal'],
#  [u'buy', u'second', u'hand', u'motorcycl', u'famili'],
#  [u'stock', u'inventori'],
#  [u'buy', u'bead', u'embroideri', u'thread', u'embroideri', u'busi'],
#  [u'buy', u'fruit', u'veget'],
#  [u'purchas', u'thread', u'machin', u'servic', u'two', u'machin', u'workshop'],
#  [u'buy', u'milk', u'cow'],
#  [u'purchas', u'merchandis', u're', u'stock', u'shop'],
#  [u'purchas', u'raw', u'materi', u'smoke', u'fish', u'product'],
#  [u'purchas', u'sugar', u'rice', u'chicken', u'lettuc'],
#  [u'increas', u'busi', u'size'],
#  [u'buy', u'fertil', u'potato', u'cereal', u'sell', u'citi'],
#  [u'busi', u'support', u'purchas', u'good', u'new', u'year'],
#  [u'pay', u'school', u'fee', u'increas', u'capac', u'group', u's', u'busi'],
#  [u'buy', u'junk', u'stuff', u'stock', u'gener', u'incom'],
#  [u'loan', u'will', u'buy', u'product', u'make', u'shoe'],
#  [u'purchas', u'second', u'hand', u'refriger', u'merchandis'],
#  [u'purchas', u'merchandis', u'increas', u'sale'],
#  [u'purchas',
#   u'sew',
#   u'machin',
#   u'sew',
#   u'materi',
#   u'inventori',
#   u'gener',
#   u'store'],
#  [u'purchas', u'wheat', u'flour', u'cook', u'oil'],
#  [u'need', u'loan', u'invest', u'purchas', u'timber', u'payment', u'workmen'],
#  [u'purchas', u'stone', u'quarri', u'iron'],
#  [u'work', u'capit', u'purchas', u'product', u'greater', u'quantiti'],
#  [u'inventori', u'sale', u'peanut'],
#  [u'purchas', u'duck', u'rais'],
#  [u'buy',
#   u'fri',
#   u'pan',
#   u'big',
#   u'spoon',
#   u'cook',
#   u'pot',
#   u'veget',
#   u'oil',
#   u'salt'],
#  [u'pour',
#   u'achet',
#   u't',
#   u'te',
#   u'de',
#   u'poussin',
#   u'et',
#   u'de',
#   u'sac',
#   u'de',
#   u'provend'],
#  [u'purchas', u'silk', u'materi', u'weav', u'busi'],
#  [u'build', u'rent', u'room'],
#  [u'procur', u'ingredi'],
#  [u'buy', u'materi', u'photographi', u'busi'],
#  [u'purchas', u'women', u's', u'shoe', u'sell'],
#  [u'addtion', u'capit', u'food', u'vend'],
#  [u'increas', u'product', u'turnov'],
#  [u'replac', u'exist', u'taxi'],
#  [u'increas', u'stock', u'good', u'store'],
#  [u'increas', u'inventori', u'work', u'capit'],
#  [u'purchas', u'fish', u'tool'],
#  [u'buy', u'soft', u'drink', u'resal'],
#  [u'increas', u'merchandis'],
#  [u'achat', u'de', u'sac', u'de', u'ma', u's'],
#  [u'purchas', u'foodstuff', u'provis', u'sell'],
#  [u'purchas', u'moto', u'taxi'],
#  [u'buy', u'stall', u'market'],
#  [u'stock', u'merchandis'],
#  [u'purchas', u'bag', u'charcoal', u'sell'],
#  [u'increas', u'rang', u'good'],
#  [u'purchas', u'grain'],
#  [u'purchas', u'stock'],
#  [u'buy', u'spare', u'part'],
#  [u'buy', u'fairli', u'use', u'cloth', u'sell'],
#  [u'buy', u'materi', u'buis', u'wood', u'furnitur'],
#  [u'buy', u'cow', u'rais'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'buy', u'meat', u'rice', u'bean', u'potato', u'veget'],
#  [u'invest', u'busi'],
#  [u'buy', u'stock', u'fish', u'sell'],
#  [u'buy', u'veget'],
#  [u'buy',
#   u'corn',
#   u'corn',
#   u'husk',
#   u'sugar',
#   u'egg',
#   u'raisin',
#   u'mani',
#   u'suppli'],
#  [u'purchas', u'construct', u'materi', u'make', u'home', u'improv'],
#  [u'purchas', u'notebook', u'book', u'stationeri'],
#  [u'buy', u'fertil', u'take', u'care', u'coffe', u'crop'],
#  [u'buy', u'quantiti', u'varieti', u'product'],
#  [u'compra',
#   u'de',
#   u'insumo',
#   u'agr',
#   u'cola',
#   u'sement',
#   u'fertilizant',
#   u'e',
#   u'outro'],
#  [u'buy', u'hardwar', u'item', u'busi'],
#  [u'purchas', u'addit', u'seed', u'seedl', u'young', u'crop', u'rais'],
#  [u'buy', u'copper', u'will', u'sell', u'transform'],
#  [u'purchas', u'stock', u'retail', u'store'],
#  [u'buy', u'duck', u'egg', u'resel'],
#  [u'buy', u'cloth', u'accessori', u'sell'],
#  [u'purchas', u'stock', u'bean', u'wheat', u'flour', u'cook', u'oil', u'rice'],
#  [u'purchas', u'phone', u'comput', u'batteri', u'mobil', u'phone', u'etc'],
#  [u'purchas', u'sack', u'groundnut', u'sale'],
#  [u'stock', u'beauti', u'product'],
#  [u'build', u'room', u'rent'],
#  [u'purchas', u'fruit', u'stock', u'sweet'],
#  [u'buy',
#   u'groceri',
#   u'bakeri',
#   u'product',
#   u'can',
#   u'good',
#   u'drink',
#   u'fruit',
#   u'veget'],
#  [u'pay', u'purchas', u'insur', u'dairi', u'cow'],
#  [u'buy', u'sew', u'machin'],
#  [u'pay', u'fertilis', u'weed', u'killer', u'small', u'farm', u'equip'],
#  [u'purchas', u'fish', u'gear', u'equip'],
#  [u'buy', u'veget', u'sell', u'market'],
#  [u'purchas', u'dish', u'suppli'],
#  [u'pay', u'univers', u'fee', u'school', u'materi'],
#  [u'pay', u'labor', u'will', u'facilit', u'rice', u'farm', u'season'],
#  [u'buy',
#   u'fresh',
#   u'tomato',
#   u'red',
#   u'onion',
#   u'shallot',
#   u'chive',
#   u'celeri',
#   u'parsley'],
#  [u'purchas', u'good', u'shampoo', u'soap', u'toothpast', u'can', u'good'],
#  [u'buy', u'cloth', u'resal'],
#  [u'buy', u'fertil', u'manur', u'crop'],
#  [u'expand', u'busi', u'increas', u'turnov'],
#  [u'purchas', u'groceri', u'product'],
#  [u'buy', u'cloth'],
#  [u'buy', u'miner', u'fertil', u'fuel', u'well', u'pay', u'cost', u'labor'],
#  [u'buy', u'food', u'product', u'resal'],
#  [u'purchas', u'soap', u'deterg'],
#  [u'purchas', u'addit', u'seed', u'seedl', u'young', u'crop', u'rais'],
#  [u'buy', u'cloth', u'sell'],
#  [u'buy', u'fabric'],
#  [u'veronica', u'like', u'buy', u'hybrid', u'dairi', u'cow'],
#  [u'buy', u'new', u'busi', u'equip'],
#  [u'buy', u'equip', u'fenc', u'knive', u'glove'],
#  [u'purchas', u'product', u'equip'],
#  [u'remodelaci', u'n'],
#  [u'buy', u'food', u'buy', u'good', u'buy', u'drink', u'product'],
#  [u'purchas',
#   u'necessari',
#   u'ingredi',
#   u'corn',
#   u'fruit',
#   u'honey',
#   u'milk',
#   u'rice',
#   u'prepar',
#   u'food'],
#  [u'buy', u'necessari', u'materi', u'improv', u'busi'],
#  [u'purchas',
#   u'dog',
#   u'shampoo',
#   u'perfum',
#   u'collar',
#   u'cloth',
#   u'bed',
#   u'etc'],
#  [u'patrick',
#   u'want',
#   u'buy',
#   u'new',
#   u'bicycl',
#   u'duku',
#   u'want',
#   u'buy',
#   u'medicin',
#   u'ami',
#   u'want',
#   u'buy',
#   u'book',
#   u'pen'],
#  [u'fill', u'land', u'around', u'famili', u'hous'],
#  [u'loan', u'will', u'buy', u'product', u'need', u'sell'],
#  [u'purchas', u'motorcycl'],
#  [u'buy', u'watermelon', u'sell'],
#  [u'purchas',
#   u'costum',
#   u'jewelri',
#   u'length',
#   u'african',
#   u'print',
#   u'cloth',
#   u'pagn',
#   u'p',
#   u'achat',
#   u'de',
#   u'bijoux',
#   u'et',
#   u'de',
#   u'pi',
#   u'ce',
#   u'de',
#   u'pagn'],
#  [u'buy', u'ingredi', u'order', u'cook', u'delici', u'soup', u'custom'],
#  [u'buy',
#   u'basic',
#   u'need',
#   u'item',
#   u'rice',
#   u'sugar',
#   u'milk',
#   u'oil',
#   u'etc'],
#  [u'buy',
#   u'medicin',
#   u'chestcof',
#   u'strepsil',
#   u'mucolyn',
#   u'hedex',
#   u'other'],
#  [u'comprar', u'materi', u'por', u'docena'],
#  [u'expand', u'poultri', u'pig', u'busi'],
#  [u'buy', u'groceri', u'good', u'custom'],
#  [u'loan', u'will', u'use', u'upgrad', u'condit', u'hous'],
#  [u'buy', u'fish', u'sell', u'pay', u'school', u'fee'],
#  [u'fix', u'leaki', u'roof', u'famili', u'home'],
#  [u'purchas', u'addit', u'merchandis'],
#  [u'purchas', u'construct', u'materi'],
#  [u'buy', u'flour', u'sugar', u'butter'],
#  [u'bolster', u'busi'],
#  [u'busi', u'expans'],
#  [u'purchas', u'piglet', u'rais'],
#  [u'purchas',
#   u'cattl',
#   u'expand',
#   u'busi',
#   u'improv',
#   u'famili',
#   u's',
#   u'live',
#   u'condit'],
#  [u'repair', u'fish', u'boat'],
#  [u'buy', u'merchandis', u'resel'],
#  [u'expand', u'food', u'sale', u'busi'],
#  [u'purchas', u'slipper', u'children', u's', u'cloth', u'toiletri'],
#  [u'para', u'la', u'compra', u'de', u'arroz', u'az', u'car'],
#  [u'request',
#   u'loan',
#   u'buy',
#   u'motorbik',
#   u'transport',
#   u'duck',
#   u'egg',
#   u'sell',
#   u'local',
#   u'market'],
#  [u'invest', u'purchas', u'merchandis'],
#  [u'purchas', u'food', u'product', u'resel'],
#  [u'purchas', u'groceri', u'order', u'increas', u'product'],
#  [u'buy', u'cereal', u'bulk', u'sell'],
#  [u'buy', u'farm', u'suppli'],
#  [u'buy',
#   u'sugar',
#   u'rice',
#   u'meat',
#   u'candi',
#   u'cereal',
#   u'cloth',
#   u'wood',
#   u'flower'],
#  [u'buy', u'pig', u'sell', u'meat', u'food', u'product', u'made', u'meat'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'buy', u'egg'],
#  [u'buy', u'manur', u'farm', u'input'],
#  [u'invest', u'expand', u'busi'],
#  [u'repair', u'husband', u's', u'taxi'],
#  [u'tomato', u'crop'],
#  [u'buy', u'carbon', u'drink', u'ingredi', u'make', u'salchipapa', u'sell'],
#  [u'addit', u'capit', u'sari', u'sari', u'store'],
#  [u'buy', u'stock', u'coffe'],
#  [u'buy', u'fertil', u'improv', u'product'],
#  [u'expand', u'busi'],
#  [u'buy', u'cloth', u'shoe', u'merchandis'],
#  [u'work', u'capit'],
#  [u'tool', u'supplo'],
#  [u'increas', u'stock', u'groceri', u'product'],
#  [u'buy', u'fertil', u'seed', u'farm', u'land'],
#  [u'buy', u'cloth'],
#  [u'purchas', u'addit', u'product', u'buy', u'sell'],
#  [u'build', u'hous', u'rent', u'room', u'pay', u'purchas', u'motorcycl'],
#  [u'buy', u'addit', u'inventori', u'work', u'capit'],
#  [u'buy', u'merchandis', u'varieti', u'store'],
#  [u'buy', u'cattl', u'feed'],
#  [u'purchas', u'manur', u'farm', u'garden'],
#  [u'purchas',
#   u'sack',
#   u'bean',
#   u'wheat',
#   u'flour',
#   u'cook',
#   u'fat',
#   u'oil',
#   u'rice'],
#  [u'purchas', u'chicken', u'rais', u'sell'],
#  [u'pay', u'educ', u'expens'],
#  [u'buy',
#   u'varieti',
#   u'men',
#   u's',
#   u'women',
#   u's',
#   u'cloth',
#   u'can',
#   u'increas',
#   u'sale',
#   u'household',
#   u'incom'],
#  [u'purchas', u'fish', u'sell'],
#  [u'buy', u'paraffin', u'sale'],
#  [u'buy', u'can', u'good', u'snack', u'beverag'],
#  [u'buy', u'fruit', u'cereal'],
#  [u'buy', u'motorbik', u'husband', u'travel', u'work'],
#  [u'buy', u'cattl', u'sell', u'increas', u'profit'],
#  [u'buy', u'fish', u'shrimp', u'prawn', u'type', u'seafood'],
#  [u'buy', u'sew', u'machin'],
#  [u'buy', u'shoe', u'belt', u'leather', u'jacket', u'sale'],
#  [u'purchas', u'pop', u'juic', u'bread', u'water', u'item', u'busi'],
#  [u'buy', u'lumber', u'paint', u'decor'],
#  [u'pay', u'field', u'worker'],
#  [u'purchas', u'veget', u'fruit', u'poultri'],
#  [u'purchas', u'inventori', u'wife', u's', u'cloth', u'shop'],
#  [u'buy', u'materi', u'need', u'billiard', u'hall'],
#  [u'purchas', u'suppli'],
#  [u'buy',
#   u'second',
#   u'hand',
#   u'motorcycl',
#   u'son',
#   u'start',
#   u'provid',
#   u'motorcycl',
#   u'servic'],
#  [u'sourc',
#   u'farm',
#   u'input',
#   u'seed',
#   u'fertil',
#   u'low',
#   u'price',
#   u'plant',
#   u'season'],
#  [u'buy', u'pair', u'oxen', u'farm', u'busi'],
#  [u'buy', u'item', u'sell', u'custom'],
#  [u'hire', u'day', u'labor'],
#  [u'buy', u'femal', u'guinea', u'pig'],
#  [u'buy', u'stationari', u'materi', u'shop'],
#  [u'frai',
#   u'de',
#   u'labour',
#   u'achat',
#   u'd',
#   u'intrant',
#   u'et',
#   u'de',
#   u'semenc'],
#  [u'purchas', u'differ', u'type', u'sew', u'machin'],
#  [u'build', u'shed', u'fpr', u'cow', u'buy', u'sheep'],
#  [u'seed', u'garden', u'equip', u'purchas'],
#  [u'increas', u'varieti', u'good'],
#  [u'purchas', u'paint', u'brush', u'roll', u'cotton', u'materi'],
#  [u'purchas', u'cow'],
#  [u'purchas', u'sugar', u'drink'],
#  [u'purchas', u'ingredi', u'elabor', u'specialti', u'bread'],
#  [u'buy',
#   u'rice',
#   u'can',
#   u'product',
#   u'tomato',
#   u'fish',
#   u'oil',
#   u'sell',
#   u'peopl',
#   u'local',
#   u'festiv',
#   u'baka',
#   u'tue',
#   u'just',
#   u'begin',
#   u'store',
#   u'christma',
#   u'sale'],
#  [u'purchas', u'candi', u'sweet', u'sell', u'sweet', u'gift', u'kid'],
#  [u'expand', u'rang', u'cloth'],
#  [u'purchas', u'construct', u'materi'],
#  [u'loan',
#   u'will',
#   u'use',
#   u'purchas',
#   u'noodl',
#   u'rice',
#   u'cook',
#   u'oil',
#   u'milk',
#   u'egg',
#   u'potato',
#   u'tuna',
#   u'tara',
#   u'cochinilla',
#   u'appl',
#   u'orang',
#   u'banana',
#   u'cooki',
#   u'candi',
#   u'chocol',
#   u'sand',
#   u'pay',
#   u'labor'],
#  [u'purchas', u'merchandis'],
#  [u'purchas', u'assort', u'fruit', u'merchandis', u'increas', u'sale'],
#  [u'purchas', u'merchandis'],
#  [u'purchas', u'cloth', u'peanut', u'misc'],
#  [u'invest', u'materi', u'busi'],
#  [u'purchas',
#   u'box',
#   u'condens',
#   u'milk',
#   u'box',
#   u'spaghetti',
#   u'variou',
#   u'good'],
#  [u'build', u'wall', u'hous'],
#  [u'buy', u'four', u'piglet', u'breed'],
#  [u'add',
#   u'save',
#   u'buy',
#   u'timber',
#   u'build',
#   u'hous',
#   u'famili',
#   u'live',
#   u'better',
#   u'condit'],
#  [u'purchas', u'car', u'part', u'timber', u'renov', u'hous'],
#  [u'buy', u'mason', u'tool'],
#  [u'purchas', u'groceri', u'item', u'sale', u'use', u'poultri', u'busi'],
#  [u'buy', u'product', u'laundromat'],
#  [u'buy', u'book', u'sell', u'bookstor'],
#  [u'purchas', u'kitchen', u'utensil', u'sell'],
#  [u'product', u'sale', u'peanut', u'butter'],
#  [u'build', u'fenc', u'farm'],
#  [u'buy', u'mobil', u'phone', u'accessori', u'busi'],
#  [u'expand', u'inventori'],
#  [u'purchas', u'addit', u'inventori', u'provid', u'work', u'capit'],
#  [u'purchas', u'item', u'sell', u'well', u'rice', u'bulk', u'resal'],
#  [u'increas', u'stock', u'electr', u'good'],
#  [u'work', u'capit'],
#  [u'buy', u'sheet', u'steel'],
#  [u'purchas', u'foodstuff', u'cook', u'sell'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'purchas', u'seed', u'fertil'],
#  [u'build', u'wall', u'near', u'back', u'door'],
#  [u'increas', u'work', u'capit', u'develop', u'busi'],
#  [u'replenish', u'stock', u'broom', u'peanut', u'past', u'palm', u'oil'],
#  [u'home', u'improv'],
#  [u'obtain',
#   u'fish',
#   u'resel',
#   u'buy',
#   u'addit',
#   u'merchandis',
#   u'sari',
#   u'sari',
#   u'store'],
#  [u'buy', u'necessari', u'materi', u'busi'],
#  [u'buy', u'fabric', u'shirt'],
#  [u'increas', u'work', u'capit'],
#  [u'purchas', u'cloth', u'busi'],
#  [u'financ', u'make', u'new', u'fish', u'boat'],
#  [u'purchas', u'new', u'item', u'expand', u'product', u'offer'],
#  [u'work', u'capit'],
#  [u'buy', u'soft', u'drink', u'sweet', u'kid', u'beauti', u'suppli'],
#  [u'addit', u'work', u'capit'],
#  [u'secur',
#   u'new',
#   u'client',
#   u'green',
#   u'janitori',
#   u'servic',
#   u'increas',
#   u'capit',
#   u'flow'],
#  [u'beer', u'stock', u'pub'],
#  [u'buy', u'sew', u'suppli'],
#  [u'oper', u'capit', u'requir', u'rais', u'anim'],
#  [u'buy', u'sorghum', u'cattl', u'feed', u'bulk'],
#  [u'purchas',
#   u'construct',
#   u'materi',
#   u'tile',
#   u'cement',
#   u'glue',
#   u'labor',
#   u'other'],
#  [u'purchas', u'cloth', u'especi', u'women'],
#  [u'buy', u'plumb', u'suppli', u'sale'],
#  [u'cement', u'block', u'sand'],
#  [u'fund', u'oper', u'farm'],
#  [u'increas', u'store', u's', u'inventori'],
#  [u'buy', u'merchandis', u'fruit', u'stock', u'busi'],
#  [u'buy', u'product', u'busi'],
#  [u'purchas', u'gener', u'merchandis', u'resel'],
#  [u'buy', u'addit', u'metal', u'resel'],
#  [u'buy', u'groceri', u'resel'],
#  [u'buy',
#   u'groceri',
#   u'fruit',
#   u'veget',
#   u'also',
#   u'buy',
#   u'metal',
#   u'grill',
#   u'protect',
#   u'store',
#   u'improv',
#   u'infrastructur'],
#  [u'buy', u'second', u'hand', u'cloth', u'shoe'],
#  [u'buy', u'new', u'larg', u'gener'],
#  [u'purchas', u'calv'],
#  [u'pay', u'cloth'],
#  [u'increas',
#   u'food',
#   u'shop',
#   u's',
#   u'assort',
#   u'buy',
#   u'larg',
#   u'lot',
#   u'ice',
#   u'cream',
#   u'busi'],
#  [u'buy', u'embroideri', u'materi', u'fabric'],
#  [u'purchas',
#   u'product',
#   u'fertil',
#   u'manur',
#   u'purchas',
#   u'feed',
#   u'poultri'],
#  [u'buy', u'pineappl', u'seed'],
#  [u'pay', u'univers', u'fee', u'purchas', u'book', u'binder'],
#  [u'buy', u'construct', u'materi', u'build', u'room'],
#  [u'buy',
#   u'airtel',
#   u'mtn',
#   u'azur',
#   u'warid',
#   u'pre',
#   u'paid',
#   u'phone',
#   u'card'],
#  [u'purchas', u'plot', u'land'],
#  [u'build', u'room', u'wood'],
#  [u'purchas', u'cosmet', u'wholesal', u'price'],
#  [u'boost', u'transport', u'busi', u'add', u'stock', u'cloth'],
#  [u'purchas', u'seed', u'fertil', u'corn', u'farm'],
#  [u'purchas', u'farm', u'input', u'agricultur', u'busi'],
#  [u'sourc',
#   u'farm',
#   u'input',
#   u'seed',
#   u'fertil',
#   u'low',
#   u'price',
#   u'plant',
#   u'season'],
#  [u'buy', u'wood', u'materi'],
#  [u'buy',
#   u'flour',
#   u'spice',
#   u'chickpea',
#   u'make',
#   u'gol',
#   u'gappay',
#   u'fast',
#   u'food',
#   u'item'],
#  [u'purchas', u'groceri', u'sell'],
#  [u'buy', u'cattl'],
#  [u'achet', u'de', u'chaussur', u'et', u'du', u'charbon', u'de', u'boi'],
#  [u'want',
#   u'buy',
#   u'pipe',
#   u'sprinkler',
#   u'fit',
#   u'irrig',
#   u'purpos',
#   u'will',
#   u'plant',
#   u'kale',
#   u'meet',
#   u'local',
#   u'demand'],
#  [u'purchas', u'suppli'],
#  [u'purchas', u'flour', u'sugar', u'rice', u'noodl', u'oil', u'etc'],
#  [u'buy', u'dye', u'shampoo', u'hair', u'dryer', u'etc'],
#  [u'janet',
#   u'plan',
#   u'use',
#   u'loan',
#   u'buy',
#   u'new',
#   u'tire',
#   u'much',
#   u'need',
#   u'mainten',
#   u'matatoo',
#   u'taxi'],
#  [u'buy', u'new', u'tire', u'cylind', u'moto', u'taxi'],
#  [u'purchas',
#   u'carpentri',
#   u'tool',
#   u'suppli',
#   u'husband',
#   u'expand',
#   u'product'],
#  [u'purchas', u'addit', u'chicken', u'rais', u'sell'],
#  [u'purchas', u'construct', u'tool'],
#  [u'purchas', u'cloth', u'suppli', u'small', u'busi'],
#  [u'purchas',
#   u'merchandis',
#   u'meat',
#   u'can',
#   u'good',
#   u'dairi',
#   u'product',
#   u'sweet',
#   u'treat',
#   u'clean',
#   u'product',
#   u'bread',
#   u'noodl',
#   u'etc'],
#  [u'purchas', u'wood', u'repair', u'home'],
#  [u'purchas', u'sew', u'materi', u'pagn', u'decor', u'cloth'],
#  [u'purchas', u'fish', u'net', u'piglet', u'rais'],
#  [u'purchas', u'varieti', u'groceri', u'product'],
#  [u'buy',
#   u'maiz',
#   u'flour',
#   u'rice',
#   u'bean',
#   u'soap',
#   u'sugar',
#   u'tea',
#   u'leav'],
#  [u'repair', u'hous'],
#  [u'purchas', u'silk', u'materi', u'weav'],
#  [u'purchas', u'gromoxon', u'sting', u'farm', u'busi'],
#  [u'purchas', u'tool', u'diesel', u'car', u'repair', u'busi'],
#  [u'buy', u'iron', u'sell', u'scrap', u'sell', u'auto', u'rickshaw'],
#  [u'para',
#   u'adquirir',
#   u'm',
#   u's',
#   u'mercad',
#   u'como',
#   u'galleta',
#   u'bebida',
#   u'fruta'],
#  [u'purchas', u'perfum'],
#  [u'buy',
#   u'sack',
#   u'corn',
#   u'bean',
#   u'cassava',
#   u'flour',
#   u'rice',
#   u'condiment',
#   u'make',
#   u'sauc'],
#  [u'buy', u'ingredi', u'cooki', u'bread', u'make'],
#  [u'employ', u'labor', u'farm', u'pay', u'school', u'fee'],
#  [u'feed', u'sale', u'cattl'],
#  [u'purchas', u'addit', u'inventori'],
#  [u'increas',
#   u'stock',
#   u'fish',
#   u'buy',
#   u'cattl',
#   u'order',
#   u'diversifi',
#   u'busi'],
#  [u'expand', u'product', u'offer', u'store'],
#  [u'buy', u'engin'],
#  [u'ask', u'loan', u'buy', u'two', u'piglet', u'breed'],
#  [u'achat', u'de', u'produit', u'd', u'aliment', u'g', u'n', u'rale'],
#  [u'purchas', u'electr', u'good', u'sell'],
#  [u'purchas', u'addit', u'equip', u'need', u'tire', u'repair'],
#  [u'work', u'capit'],
#  [u'purchas', u'bed', u'sheet', u'curtain', u'meat'],
#  [u'purchas', u'shoe', u'sale'],
#  [u'buy', u'fresh', u'fish'],
#  [u'mejoramiento', u'de', u'vivienda'],
#  [u'bolster', u'work', u'capit'],
#  [u'addit', u'wed', u'cloth', u'rent'],
#  [u'purchas', u'fairli', u'use', u'bag', u'sell'],
#  [u'buy', u'magazin', u'improv', u'busi'],
#  [u'purchas', u'land', u'rais', u'oxe'],
#  [u'buy', u'raw', u'silk', u'expand', u'busi'],
#  [u'purchas', u'tyre', u'husband', u's', u'busi'],
#  [u'buy', u'dri', u'fish'],
#  [u'purchas',
#   u'spice',
#   u'bulk',
#   u'resel',
#   u'retail',
#   u'goal',
#   u'increas',
#   u'profit'],
#  [u'purchas', u'compost'],
#  [u'purchas', u'cocoa', u'maiz', u'sow', u'sell'],
#  [u'purchas', u'rice', u'veget', u'sugar'],
#  [u'buy',
#   u'meat',
#   u'condiment',
#   u'ingredi',
#   u'make',
#   u'bread',
#   u'oil',
#   u'soda',
#   u'water',
#   u'cigar',
#   u'wine',
#   u'beer'],
#  [u'build', u'classroom'],
#  [u'purchas', u'car'],
#  [u'buy', u'cloth'],
#  [u'purchas', u'new', u'motorbik', u'continu', u'motor', u'taxi', u'busi'],
#  [u'purchas', u'addit', u'stock', u'veterinari', u'shop'],
#  [u'buy', u'pig'],
#  [u'purchas',
#   u'construct',
#   u'materi',
#   u'cement',
#   u'sheet',
#   u'metal',
#   u'mesh',
#   u'joist',
#   u'etc'],
#  [u'purchas', u'make', u'tool', u'product'],
#  [u'purchas', u'item', u'store'],
#  [u'purchas', u'seed', u'fertil', u'farm', u'suppli'],
#  [u'purchas', u'cattl'],
#  [u'stock', u'sugar', u'flour', u'cereal'],
#  [u'pay', u'field', u'hand'],
#  [u'purchas',
#   u'bake',
#   u'good',
#   u'meat',
#   u'legum',
#   u'beverag',
#   u'food',
#   u'product'],
#  [u'purchas', u'insur', u'dairi', u'cow'],
#  [u'buy', u'pagn', u'cloth'],
#  [u'purchas', u'sheep', u'fatten', u'resal'],
#  [u'buy', u'addit', u'stock', u'store', u'like', u'sack', u'rice'],
#  [u'buy', u'small', u'fish', u'omena'],
#  [u'buy', u'electr', u'guitar', u'band'],
#  [u'buy', u'ingredi', u'make', u'pastri', u'bread', u'oven', u'sell'],
#  [u'purchas', u'product', u'sew', u'materi', u'craft', u'articl', u'cloth'],
#  [u'purchas', u'rice', u'sugar', u'noodl', u'egg', u'deterg', u'product'],
#  [u'buy',
#   u'merchandis',
#   u'pant',
#   u'bag',
#   u'towel',
#   u'sandal',
#   u'cosmet',
#   u'cloth',
#   u'gener'],
#  [u'purchas', u'fertil', u'corn'],
#  [u'buy', u'product', u'set', u'store'],
#  [u'buy', u'beverag'],
#  [u'purchas', u'bull'],
#  [u'buy', u'goat', u'sheep', u'anim', u'sale', u'busi'],
#  [u'buy', u'hardwar', u'item'],
#  [u'purchas', u'miner', u'fertil', u'pol'],
#  [u'purchas', u'new', u'winter', u'collect', u'cloth', u'resal'],
#  [u'buy', u'veget'],
#  [u'purchas', u'feed', u'vitamin', u'school', u'suppli'],
#  [u'buy',
#   u'item',
#   u'shampoo',
#   u'groceri',
#   u'sell',
#   u'sari',
#   u'sari',
#   u'store'],
#  [u'buy', u'hair', u'color', u'cosmet', u'manicur', u'product'],
#  [u'buy', u'tabl', u'chair'],
#  [u'start', u'horticultur', u'farm'],
#  [u'salom',
#   u'want',
#   u'buy',
#   u'dairi',
#   u'meal',
#   u'improv',
#   u'seed',
#   u'agrochem'],
#  [u'purchas', u'better', u'differ', u'inventori', u'store'],
#  [u'buy', u'fertil', u'pay', u'labor'],
#  [u'purchas', u'suppli'],
#  [u'buy', u'bale', u'use', u'cloth'],
#  [u'purchas', u'timber', u'stock'],
#  [u'buy', u'chemic', u'tool', u'farm', u'make', u'home', u'improv'],
#  [u'wide', u'exist', u'assort'],
#  [u'purchas', u'sew', u'machin', u'materi', u'thread', u'etc'],
#  [u'start', u'beauti', u'salon'],
#  [u'help', u'fund', u'build', u'hous', u'daughter'],
#  [u'purchas', u'ingredi', u'meal', u'prepar'],
#  [u'buy', u'fertil'],
#  [u'increas',
#   u'profit',
#   u'order',
#   u'build',
#   u'new',
#   u'hous',
#   u'replac',
#   u'old',
#   u'one'],
#  [u'purchas', u'pagn', u'cosmet', u'resal'],
#  [u'buy', u'boat', u'fish', u'net'],
#  [u'purchas', u'product', u'suppli', u'store', u'well', u'clay', u'pot'],
#  [u'buy', u'additioin', u'brand', u'beer', u'soda'],
#  [u'buy',
#   u'fertil',
#   u'pesticid',
#   u'hire',
#   u'labor',
#   u'plant',
#   u'seedl',
#   u'harvest',
#   u'rice'],
#  [u'import', u'fruit'],
#  [u'purchas', u'children', u's', u'shoe'],
#  [u'buy', u'fish', u'charcoal'],
#  [u'purchas', u'coconut', u'fix', u'truck'],
#  [u'procur', u'palm', u'nut'],
#  [u'buy', u'cloth', u'cosmet'],
#  [u'need', u'sole', u'loan', u'buy', u'fabric', u'sheet'],
#  [u'replenish', u'suppli'],
#  [u'purchas', u'oat', u'seed', u'fertil'],
#  [u'purchas', u'new', u'use', u'cloth', u'retail'],
#  [u'purchas', u'auto', u'part'],
#  [],
#  [u'purchas', u'wholesal', u'cloth'],
#  [u'buy', u'net', u'fish', u'etc'],
#  [u'surtir', u'su', u'negocio'],
#  [u'purchas', u'young', u'cattl'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'purchas', u'fertil', u'fungicid'],
#  [u'purchas', u'assort', u'good'],
#  [u'buy', u'leather', u'shoe', u'sole', u'cloth'],
#  [u'buy', u'provis'],
#  [u'buy', u'cell', u'phone'],
#  [u'buy', u'crate', u'soda', u'miner', u'water', u'box', u'fruit'],
#  [u'purchas', u'iron', u'work', u'mainten', u'work', u'car'],
#  [u'oper', u'capit', u'vehicl', u'repair'],
#  [u'restock',
#   u'retail',
#   u'shop',
#   u'item',
#   u'like',
#   u'sugar',
#   u'oil',
#   u'cereal'],
#  [u'purchas', u'addit', u'inventori', u'work', u'capit'],
#  [u'buy', u'fruit', u'veget'],
#  [u'oper', u'capit', u'rais', u'chicken'],
#  [u'purchas', u'requir', u'item', u'soft', u'drink', u'busi'],
#  [u'buy', u'grade', u'cow'],
#  [u'buy', u'stapl'],
#  [u'purchas', u'seed', u'increas', u'product'],
#  [u'purchas', u'addit', u'merchandis'],
#  [u'buy', u'construct', u'materi'],
#  [u'purchas', u'fertil'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'buy', u'cloth', u'christma', u'decor', u'resal'],
#  [u'purchas', u'insur', u'dairi', u'cow'],
#  [u'repair', u'transport', u'vehicl', u'use', u'busi'],
#  [u'purchas', u'addit', u'product'],
#  [u'buy', u'bean', u'sorghum', u'sell'],
#  [u'purchas', u'agricultur', u'tool', u'suppli'],
#  [u'buy', u'merchandis', u'store'],
#  [u'buy', u'cloth', u'add', u'stock'],
#  [u'buy', u'ingredi'],
#  [u'purchas', u'groceri'],
#  [u'buy', u'addit', u'medic', u'drug', u'resel'],
#  [u'buy', u'merchandis'],
#  [u'buy',
#   u'pant',
#   u'shirt',
#   u'skirt',
#   u'dress',
#   u'short',
#   u'swimsuit',
#   u'sinc',
#   u'summer',
#   u'season',
#   u'approach'],
#  [u'buy', u'tire', u'pay', u'car', u'servic', u'car', u'wife', u's'],
#  [u'purchas', u'food', u'sweet', u'potato', u'rice', u'maiz', u'etc'],
#  [u'purchas',
#   u'young',
#   u'cattl',
#   u'order',
#   u'expand',
#   u'busi',
#   u'improv',
#   u'live',
#   u'condit',
#   u'famili'],
#  [u'buy', u't', u'shirt', u'blous', u'sell'],
#  [u'buy', u'cook', u'fat', u'rice', u'sugar'],
#  [u'purchas', u'tomato', u'passion', u'fruit', u'mango', u'resal'],
#  [u'purchas', u'bag', u'backpack', u'handcraft', u'item'],
#  [u'buy', u'perfum', u'notebook', u'pencil', u'cloth', u'costum', u'jewelri'],
#  [u'tile', u'room'],
#  [u'buy', u'raw', u'materi', u'fabric', u'thread', u'needl'],
#  [u'buy', u'fish', u'sell'],
#  [u'buy', u'tabl', u'chair'],
#  [u'buy', u'build', u'suppli'],
#  [u'boost', u'farm'],
#  [u'buy', u'anoth', u'sew', u'machin'],
#  [u'buy', u'fish', u'sell'],
#  [u'buy', u'brake', u'pad', u'disc'],
#  [u'buy', u'maiz', u'flour', u'sugar'],
#  [u'purchas', u'gener', u'farm', u'suppli', u'equip'],
#  [u'buy', u'laboratori', u'product'],
#  [u'buy', u'raw', u'materi', u'busi'],
#  [u'buy', u'construct', u'materi'],
#  [u'pay', u'plow', u'fee', u'cash', u'crop'],
#  [u'buy', u'calv', u'expand', u'busi'],
#  [u'buy', u'merchandis', u'resal', u'shop'],
#  [u'buy', u'duck', u'fish', u'food'],
#  [u'buy', u'merchandis', u're', u'sale'],
#  [u'increas', u'current', u'stock', u'level'],
#  [u'buy', u'soft', u'drink', u'provis', u'cloth', u'materi', u'shop'],
#  [u'purchas', u'shellfish'],
#  [u'buy',
#   u'variou',
#   u'item',
#   u'women',
#   u's',
#   u'busi',
#   u'includ',
#   u'food',
#   u'clean',
#   u'item',
#   u'cloth',
#   u'home',
#   u'good'],
#  [u'increas', u'capit', u'maintain', u'busi', u'increas', u'incom', u'famili'],
#  [u'purchas', u'motorcycl', u'reduc', u'travel', u'transport', u'expens'],
#  [u'purchas', u'leather', u'retail', u'zipper'],
#  [u'purchas', u'water', u'pump', u'fertil', u'seed', u'ga'],
#  [u'purchas', u'merchandis'],
#  [u'buy', u'cosmet', u'sanitari', u'product', u'sell'],
#  [u'purchas',
#   u'plot',
#   u'farmland',
#   u'one',
#   u'hectar',
#   u'use',
#   u'increas',
#   u'rice',
#   u'crop'],
#  [u'purchas', u'electron', u'applianc', u'home'],
#  [u'buy', u'hors', u'cart', u'husband'],
#  [u'buy', u'sack', u'corn', u'rice', u'cater'],
#  [u'increas', u'milk', u'suppli', u'expand', u'busi'],
#  [u'purchas', u'land', u'work', u'rais', u'livestock'],
#  [u'fund', u'electron', u'load', u'busi'],
#  [u'acquir',
#   u'merchandis',
#   u'oil',
#   u'gallon',
#   u'quarter',
#   u'contain',
#   u'quick',
#   u'oil',
#   u'chang'],
#  [u'buy', u'cloth', u'sell', u'summer', u'season'],
#  [u'upgrad', u'comput'],
#  [u'purchas', u'stock', u'cosmet'],
#  [u'purchas', u'foodstuff', u'cook', u'sell'],
#  [u'purchas', u'crop', u'bulk', u'busi'],
#  [u'purchas',
#   u'two',
#   u'cow',
#   u'one',
#   u'hen',
#   u'increas',
#   u'inventori',
#   u'shop',
#   u'furnitur'],
#  [u'buy', u'season', u'veget', u'sell'],
#  [u'buy', u'silk', u'weav'],
#  [u'incremento', u'de', u'mercad'],
#  [u'buy', u'rice', u'seed', u'fertil'],
#  [u'buy', u'spare', u'part'],
#  [u'purchas', u'bag', u'shoe', u'cloth', u'sell'],
#  [u'purchas', u'addit', u'equip', u'vulcan', u'shop'],
#  [u'addit', u'capit', u'purchas', u'feed', u'hog'],
#  [u'invest', u'improv', u'busi'],
#  [u'buy', u'grind', u'drill', u'machin'],
#  [u'purchas', u'cosmet', u'cloth'],
#  [u'invest', u'expand', u'busi'],
#  [u'mainten', u'work', u'van'],
#  [u'buy', u'materi', u'wood', u'cedar', u'walnut', u'peterebi'],
#  [u'purchas', u'uniform', u'school', u'suppli'],
#  [u'buy',
#   u'variou',
#   u'kind',
#   u'rice',
#   u'brown',
#   u'white',
#   u'sugar',
#   u'chicken'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'buy', u'motorbik', u'commut', u'work'],
#  [u'invest', u'expand', u'busi'],
#  [u'instal', u'metal', u'gate'],
#  [u'increas', u'work', u'capit'],
#  [u'buy', u'electron', u'add', u'shop'],
#  [u'buy', u'potato'],
#  [u'buy', u'coffe', u'corn', u'seed', u'increas', u'busi'],
#  [u'purchas', u'new', u'item', u'expand', u'product', u'offer'],
#  [u'buy', u'fuel', u'bu'],
#  [u'addit', u'capit', u'buy', u'sell', u'pig'],
#  [u'purchas', u'empti', u'shell', u'repair', u'fish', u'boat'],
#  [u'buy', u'comput'],
#  [u'purchas', u'undergar', u'sell'],
#  [u'purchas', u'sack', u'maiz'],
#  [u'purchas', u'duck', u'feed', u'vitamin'],
#  [u'purchas', u'raw', u'materi'],
#  [u'buy', u'maiz', u'make', u'kenkey', u'sell', u'custom'],
#  [u'purchas',
#   u'sack',
#   u'bean',
#   u'rice',
#   u'wheat',
#   u'flour',
#   u'cook',
#   u'oil',
#   u'charcoal',
#   u'cook'],
#  [u'purchas', u'fabric', u'kitchenwar'],
#  [u'buy', u'seed', u'fertil', u'young', u'cattl'],
#  [u'purchas', u'varieti', u'fruit', u'sell'],
#  [u'buy', u'materi', u'sew', u'busi'],
#  [u'purchas', u'cloth', u'merchandis'],
#  [u'buy', u'embroideri', u'thread'],
#  [u'purchas', u'watermelon', u'orang', u'bread', u'toy', u'sell', u'store'],
#  [u'purchas', u'merchandis', u'sell'],
#  [u'stock', u'plant', u'nurseri'],
#  [u'purchas',
#   u'bundl',
#   u'sugar',
#   u'wheat',
#   u'flour',
#   u'maiz',
#   u'flour',
#   u'cook',
#   u'fat',
#   u'oil',
#   u'salt'],
#  [u'buy', u'cereal'],
#  [u'purchas', u'basic', u'consum', u'good', u'rice', u'sugar', u'product'],
#  [u'buy', u'fertil', u'hybrid', u'seed', u'rice', u'herbicid', u'farm'],
#  [u'increas', u'fish', u'can', u'buy', u'enhanc', u'sale'],
#  [u'buy', u'furnitur', u'beauti', u'salon'],
#  [u'buy', u'sheet', u'towel', u'perfum', u'shoe', u'cream', u'merchandis'],
#  [u'buy', u'raw', u'materi', u'need', u'tailor', u'like', u'cloth'],
#  [u'buy', u'grind', u'machin', u'salt'],
#  [u'buy', u'flour', u'bean', u'ingredi'],
#  [u'buy', u'scissor', u'gel', u'comb', u'other'],
#  [u'grow', u'rice', u'rais', u'pig'],
#  [u'purchas', u'fertil', u'rice', u'seed'],
#  [u'open', u'tailor', u'busi', u'wife'],
#  [u'buy', u'second', u'hand', u'cloth'],
#  [u'hire', u'worker', u'harvest', u'maiz', u'crop'],
#  [u'buy', u'shoe', u'sugar', u'sell'],
#  [u'buy', u'tool', u'pay', u'gasolin', u'servic'],
#  [u'buy', u'cloth', u'resel'],
#  [u'buy', u'camera', u'photo', u'album', u'film', u'etc'],
#  [u'buy',
#   u'candi',
#   u'sell',
#   u'can',
#   u'pay',
#   u'children',
#   u's',
#   u'school',
#   u'fee'],
#  [u'alic', u'want', u'buy', u'two', u'hybrid', u'dairi', u'cow'],
#  [u'money',
#   u'prisma',
#   u'will',
#   u'invest',
#   u'buy',
#   u'product',
#   u'vender',
#   u'will',
#   u'sell',
#   u'distribut',
#   u'co',
#   u'worker',
#   u'busi'],
#  [u'purchas',
#   u'cordial',
#   u'plastic',
#   u'cup',
#   u'mutton',
#   u'flap',
#   u'onion',
#   u'soy',
#   u'sauc',
#   u'flour',
#   u'sugar'],
#  [u'purchas', u'good', u'sale'],
#  [u'buy', u'food', u'materi', u'shop'],
#  [u'suppli',
#   u'busi',
#   u'product',
#   u'rice',
#   u'sugar',
#   u'floor',
#   u'veget',
#   u'oil',
#   u'satisfi',
#   u'client',
#   u's',
#   u'demand'],
#  [u'purchas', u'banana', u'plantain'],
#  [u'purchas', u'hammock', u'bed', u'quilt'],
#  [u'purchas', u'garment', u'increas', u'sale'],
#  [u'buy', u'materi', u'paint'],
#  [u'purchas', u'silk', u'materi', u'weav'],
#  [u'buy', u'addit', u'item', u'sell', u'custom'],
#  [u'will', u'buy', u'ingredi', u'prepar', u'food', u'make', u'sale'],
#  [u'purchas', u'cow', u'breed', u'addit', u'profit'],
#  [u'buy', u'sew', u'machin'],
#  [u'buy', u'bedsheet', u'fish', u'resal'],
#  [u'buy', u'addit', u'shoe', u'wholesal', u'sell', u'peopl', u'street'],
#  [u'complet',
#   u'busi',
#   u'place',
#   u'sell',
#   u'meal',
#   u'beer',
#   u'plu',
#   u'purchas',
#   u'meal',
#   u'ingredi',
#   u'beer'],
#  [u'purchas', u'cattl', u'breed', u'sell'],
#  [u'purchas',
#   u'carton',
#   u'assort',
#   u'drink',
#   u'bag',
#   u'sugar',
#   u'carton',
#   u'bottl',
#   u'miner',
#   u'water',
#   u'box',
#   u'biscuit',
#   u'etc'],
#  [u'purchas', u'rice', u'resal'],
#  [u'purchas', u'foodstuff', u'dri', u'fish', u'sell'],
#  [u'purchas', u'ingredi'],
#  [u'buy', u'new', u'set', u'fish', u'neta'],
#  [u'increas', u'stock', u'mobil', u'phone', u'credit', u'unit', u'transfer'],
#  [u'expand', u'store', u'inventori'],
#  [u'purchas', u'suppli', u'fertil', u'need', u'crop'],
#  [u'stock', u'pharmaci'],
#  [u'buy', u'quantiti', u'onion', u'retail'],
#  [u'car', u'repair'],
#  [],
#  [u'purchas', u'materi', u'product', u'busi'],
#  [u'addit', u'capit'],
#  [u'compra',
#   u'de',
#   u'caballo',
#   u'chucarro',
#   u'para',
#   u'reforzar',
#   u'su',
#   u'trabajo',
#   u'y',
#   u'vender'],
#  [u'buy', u'good', u'flour', u'rice', u'noodl', u'sugar', u'bread', u'like'],
#  [u'purchas', u'addit', u'inventori', u'work', u'capit'],
#  [u'purchas', u'addit', u'product', u'sell'],
#  [u'farm', u'suppli'],
#  [u'buy', u'condiment'],
#  [u'buy', u'piglet', u'rais'],
#  [u'purchas', u'seed', u'miner', u'fertil'],
#  [u'buy', u'hair', u'product', u'gel', u'shampoo', u'sheen', u'oil', u'etc'],
#  [u'purchas', u'fruit', u'sell'],
#  [u'purchas', u'wash', u'machin'],
#  [u'poultri'],
#  [u'purchas', u'babi', u'livestock', u'rais', u'sell', u'futur'],
#  [u'buy', u'weed', u'killer', u'gramoxom'],
#  [u'purchas', u'cloth', u'stock'],
#  [u'purchas', u'tailor', u'tool', u'start', u'busi'],
#  [u'purchas', u'bag', u'banana', u'charcoal', u'resal'],
#  [u'purchas', u'hair', u'product', u'use', u'custom'],
#  [u'purchas', u'farm', u'suppli', u'addit', u'fish', u'resel'],
#  [u'buy', u'heifer'],
#  [u'purchas', u'stock', u'e', u'load', u'inventori'],
#  [u'invest',
#   u'cosmet',
#   u'catalog',
#   u'product',
#   u'mexican',
#   u'snack',
#   u'sale',
#   u'cloth',
#   u'sale',
#   u'confectioneri',
#   u'shop'],
#  [u'invest', u'banku', u'busi'],
#  [u'buy', u'ga', u'convers', u'kit', u'vehicl', u'mainten', u'repair'],
#  [u'buy',
#   u'pant',
#   u't',
#   u'shirt',
#   u'blous',
#   u'shoe',
#   u'sneaker',
#   u'season',
#   u'product'],
#  [u'stock', u'gener', u'store'],
#  [u'buy', u'pig', u'concentr', u'feed'],
#  [u'buy',
#   u'materi',
#   u'like',
#   u'five',
#   u'wool',
#   u'cone',
#   u'five',
#   u'kilo',
#   u'alpaca',
#   u'wool',
#   u'well',
#   u'babi',
#   u'alpaca',
#   u'wool'],
#  [u'buy', u'yarn', u'materi', u'can', u'knit', u'item'],
#  [u'buy', u'suppli', u'feed', u'anim'],
#  [u'buy',
#   u'variou',
#   u'merchandis',
#   u'sweater',
#   u't',
#   u'shirt',
#   u'short',
#   u'blous',
#   u'pant'],
#  [u'purchas', u'ingredi', u'suppli', u'street', u'food', u'busi'],
#  [u'buy', u'meat', u'drink', u'veget', u'item', u'stock', u'store'],
#  [u'finish', u'room'],
#  [u'buy', u'groceri', u'groceri', u'store', u'busi'],
#  [u'buy', u'duck', u'egg', u'balot', u'sell'],
#  [u'purchas', u'product', u'increas', u'profit'],
#  [u'buy', u'product', u'stock', u'store'],
#  [u'buy', u'groceri', u'gener', u'store'],
#  [u'purchas', u'cloth', u'sale'],
#  [u'buy', u'addit', u'vermi', u'worm', u'make', u'fertil']]

# %% [markdown]
# ## Creating a document-term matrix

# %%
# https://rstudio-pubs-static.s3.amazonaws.com/79360_850b2a69980c4488b1db95987a24867a.html
! pip install gensim
from gensim import corpora, models
# Out:
# Requirement already satisfied: gensim in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages
# Requirement already satisfied: scipy>=0.7.0 in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from gensim)
# Requirement already satisfied: six>=1.5.0 in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from gensim)
# Requirement already satisfied: numpy>=1.3 in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from gensim)
# Requirement already satisfied: smart-open>=1.2.1 in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from gensim)
# Requirement already satisfied: boto>=2.32 in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: requests in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from smart-open>=1.2.1->gensim)
# Requirement already satisfied: bz2file in /Users/jiaminlim93/anaconda/lib/python2.7/site-packages (from smart-open>=1.2.1->gensim)
# /Users/jiaminlim93/anaconda/lib/python2.7/site-packages/gensim/utils.py:1015: UserWarning: Pattern library is not installed, lemmatization won't be available.
#   warnings.warn("Pattern library is not installed, lemmatization won't be available.")
# /Users/jiaminlim93/anaconda/lib/python2.7/site-packages/numpy/lib/utils.py:99: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   warnings.warn(depdoc, DeprecationWarning)

# %%
#type(clean_descriptions)
#isinstance(clean_descriptions[2], unicode)
#dic = corpora.Dictionary(clean_descriptions.split())
dictionary = corpora.Dictionary(clean_descriptions)

# %%
corpus = [dictionary.doc2bow(description) for description in clean_descriptions]

# %%
print sentences[20]
print clean_descriptions[20]
print(corpus[20])
# Out:
# Nimia would like to purchase cheese and the ingredients to prepare chicken relleno to sell.
# [u'nimia', u'like', u'purchas', u'chees', u'ingredi', u'prepar', u'chicken', u'relleno', u'sell']
# [(13, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1)]

# %%
len(dictionary)
# Out:
# 975

# %% [markdown]
# ## LDA model

# %% [markdown]
# ### Fitting model

# %%
from gensim import corpora, models
ldamodel = models.ldamodel.LdaModel(corpus, num_topics=5, id2word = dictionary, passes=10)
print(ldamodel.print_topics(num_topics=5, num_words=10))
# Out:
# [(0, u'0.074*"buy" + 0.058*"purchas" + 0.036*"store" + 0.031*"fish" + 0.026*"stock" + 0.021*"product" + 0.017*"sell" + 0.014*"rice" + 0.013*"sari" + 0.010*"cloth"'), (1, u'0.045*"materi" + 0.044*"purchas" + 0.030*"de" + 0.024*"buy" + 0.024*"build" + 0.021*"hous" + 0.019*"construct" + 0.011*"room" + 0.010*"wood" + 0.010*"achat"'), (2, u'0.120*"purchas" + 0.051*"sell" + 0.037*"addit" + 0.033*"buy" + 0.030*"product" + 0.025*"capit" + 0.020*"increas" + 0.020*"cloth" + 0.019*"busi" + 0.019*"work"'), (3, u'0.080*"purchas" + 0.049*"busi" + 0.033*"expand" + 0.027*"rice" + 0.025*"pay" + 0.022*"suppli" + 0.017*"invest" + 0.017*"cow" + 0.015*"sugar" + 0.014*"oil"'), (4, u'0.183*"buy" + 0.017*"busi" + 0.016*"farm" + 0.015*"fertil" + 0.013*"materi" + 0.011*"resel" + 0.010*"merchandis" + 0.010*"seed" + 0.010*"cloth" + 0.010*"product"')]

# %% [markdown]
# ### Visualisation

# %%
#h ttps://github.com/bmabey/pyLDAvis
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 2      28.421725        1       1 -0.120118 -0.054625
# 4      23.924284        1       2  0.042229 -0.113116
# 3      18.852751        1       3 -0.050505  0.175788
# 0      16.384916        1       4 -0.066790 -0.033072
# 1      12.416324        1       5  0.195184  0.025025, topic_info=     Category        Freq        Term       Total  loglift  logprob
# term
# 890   Default  341.000000         buy  341.000000  30.0000  30.0000
# 671   Default  314.000000     purchas  314.000000  29.0000  29.0000
# 849   Default   45.000000      materi   45.000000  28.0000  28.0000
# 444   Default   94.000000        sell   94.000000  27.0000  27.0000
# 395   Default   30.000000       store   30.000000  26.0000  26.0000
# 642   Default   55.000000       addit   55.000000  25.0000  25.0000
# 721   Default   33.000000      expand   33.000000  24.0000  24.0000
# 306   Default   30.000000        fish   30.000000  23.0000  23.0000
# 501   Default   96.000000        busi   96.000000  22.0000  22.0000
# 141   Default   36.000000       capit   36.000000  21.0000  21.0000
# 510   Default   23.000000          de   23.000000  20.0000  20.0000
# 690   Default   24.000000         pay   24.000000  19.0000  19.0000
# 504   Default   42.000000        rice   42.000000  18.0000  18.0000
# 452   Default   17.000000       build   17.000000  17.0000  17.0000
# 166   Default   26.000000        work   26.000000  16.0000  16.0000
# 209   Default   46.000000       stock   46.000000  15.0000  15.0000
# 163   Default   14.000000        hous   14.000000  14.0000  14.0000
# 385   Default   13.000000   construct   13.000000  13.0000  13.0000
# 518   Default   40.000000     increas   40.000000  12.0000  12.0000
# 589   Default   22.000000         cow   22.000000  11.0000  11.0000
# 965   Default   21.000000      invest   21.000000  10.0000  10.0000
# 687   Default   19.000000   inventori   19.000000   9.0000   9.0000
# 616   Default   41.000000      suppli   41.000000   8.0000   8.0000
# 210   Default   78.000000     product   78.000000   7.0000   7.0000
# 624   Default   10.000000        sari   10.000000   6.0000   6.0000
# 917   Default   13.000000       resel   13.000000   5.0000   5.0000
# 45    Default   22.000000        item   22.000000   4.0000   4.0000
# 10    Default   34.000000  merchandis   34.000000   3.0000   3.0000
# 39    Default   11.000000      school   11.000000   2.0000   2.0000
# 162   Default    7.000000        room    7.000000   1.0000   1.0000
# ...       ...         ...         ...         ...      ...      ...
# 738    Topic5    3.359691           y    4.212291   1.8600  -5.1953
# 317    Topic5    2.667796           p    3.370660   1.8523  -5.4259
# 920    Topic5    2.664031      enlarg    3.370469   1.8509  -5.4273
# 225    Topic5    2.657912       short    3.370094   1.8488  -5.4296
# 510    Topic5   18.458969          de   23.548998   1.8426  -3.4916
# 311    Topic5    3.731570          et    5.046694   1.7843  -5.0903
# 204    Topic5    1.859499        tile    2.526008   1.7798  -5.7868
# 82     Topic5    1.859479      surtir    2.526008   1.7798  -5.7869
# 933    Topic5    1.857935          az    2.525993   1.7790  -5.7877
# 260    Topic5    1.856859          la    2.525982   1.7784  -5.7883
# 967    Topic5    1.854916      cabbag    2.525951   1.7774  -5.7893
# 136    Topic5    1.844822        type    2.525961   1.7719  -5.7948
# 96     Topic5    1.829976    daughter    2.525926   1.7639  -5.8028
# 133    Topic5    5.982324        wood    8.425447   1.7437  -4.6183
# 685    Topic5    3.540052       decor    5.053090   1.7303  -5.1430
# 849    Topic5   27.451708      materi   45.163962   1.5883  -3.0947
# 815    Topic5    5.191903        home    8.409361   1.6039  -4.7601
# 400    Topic5    3.334309        para    5.043801   1.6723  -5.2029
# 339    Topic5    4.722978      compra    8.364888   1.5146  -4.8547
# 338    Topic5    2.699665      cement    4.207886   1.6423  -5.4140
# 564    Topic5    2.655288      chemic    4.206788   1.6260  -5.4306
# 361    Topic5    5.208056         sew   11.655833   1.2806  -4.7569
# 671    Topic5   26.588651     purchas  314.254538  -0.3836  -3.1267
# 859    Topic5    4.580232      repair   13.381402   1.0140  -4.8854
# 890    Topic5   14.605837         buy  341.428446  -1.0656  -3.7257
# 898    Topic5    5.906966       cloth   53.202116  -0.1118  -4.6310
# 595    Topic5    4.266398           s   21.744233   0.4576  -4.9564
# 594    Topic5    4.053722         etc   19.341585   0.5235  -5.0075
# 501    Topic5    4.632386        busi   96.052773  -0.9457  -4.8741
# 691    Topic5    3.825146        make   19.956107   0.4342  -5.0656
#
# [302 rows x 6 columns], token_table=      Topic      Freq        Term
# term
# 565       5  0.888947       achat
# 642       1  0.915820       addit
# 642       2  0.017957       addit
# 642       4  0.053872       addit
# 465       4  0.797020     addtion
# 340       2  0.807106      alpaca
# 449       2  0.909307        also
# 350       2  0.807142         ask
# 697       2  0.807137        auto
# 933       5  0.791768          az
# 810       3  0.793248        back
# 534       1  0.739025         bag
# 534       4  0.277134         bag
# 639       3  0.713362       basic
# 247       2  0.807141        bead
# 513       3  0.275287        bean
# 513       4  0.642337        bean
# 218       4  0.796842      beauti
# 858       4  0.797036       block
# 921       5  0.790255       blous
# 621       4  0.956218        boat
# 623       1  0.900861     bolster
# 94        3  0.594898         box
# 94        4  0.297449         box
# 289       1  0.602422       bread
# 289       2  0.258181       bread
# 289       5  0.086060       bread
# 868       5  0.948639       brush
# 452       2  0.056476       build
# 452       3  0.112951       build
# ...     ...       ...         ...
# 489       3  0.793265     uniform
# 126       3  0.891743     univers
# 122       1  0.350858         use
# 122       2  0.300736         use
# 122       3  0.200490         use
# 122       4  0.150368         use
# 947       1  0.359190     varieti
# 947       3  0.119730     varieti
# 947       4  0.478921     varieti
# 908       1  0.314541       veget
# 908       2  0.366965       veget
# 908       4  0.314541       veget
# 54        2  0.809436      vehicl
# 613       4  0.797026        vend
# 530       3  0.793279     vitamin
# 606       3  0.713418        wall
# 186       2  0.867640        want
# 515       1  0.800880  watermelon
# 576       1  0.721314        weav
# 835       3  0.848472       wheat
# 120       1  0.688355    wholesal
# 120       2  0.172089    wholesal
# 663       2  0.603453        will
# 663       3  0.258623        will
# 133       4  0.237376        wood
# 133       5  0.712128        wood
# 160       2  0.909286        wool
# 166       1  0.977649        work
# 636       1  0.800905    workshop
# 738       5  0.712202           y
#
# [417 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 5, 4, 1, 2])

# %%
# Might be able to convert it to html
pyLDAvis.save_html(vis, description)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-65c6656ec2b9> in <module>()
#       1 # Might be able to convert it to html
# ----> 2 pyLDAvis.save_html(vis, description)
#
# /Users/jiaminlim93/anaconda/lib/python2.7/site-packages/pyLDAvis/_display.pyc in save_html(data, fileobj, **kwargs)
#     359             fileobj = open(fileobj, 'w')
#     360     if not hasattr(fileobj, 'write'):
# --> 361         raise ValueError("fileobj should be a filename or a writable file")
#     362     fileobj.write(prepared_data_to_html(data, **kwargs))
#     363
#
# ValueError: fileobj should be a filename or a writable file
